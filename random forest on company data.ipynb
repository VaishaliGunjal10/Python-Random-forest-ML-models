# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
fnn=pd.read_csv('Company_Data.csv')
fnn
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# 0           17   Yes  Yes
# 1           10   Yes  Yes
# 2           12   Yes  Yes
# 3           14   Yes  Yes
# 4           13   Yes   No
# ..         ...   ...  ...
# 395         14   Yes  Yes
# 396         11    No  Yes
# 397         18   Yes  Yes
# 398         12   Yes  Yes
# 399         16   Yes  Yes
#
# [400 rows x 11 columns]

# %%
fn=fnn

# %%
fn['Sales']=fn['Sales'].apply(np.floor)

# %%
plt.hist(fn['Sales'],color=( 'green') )
# Out:
# (array([  7.,  29.,  41., 107.,  52.,  85.,  52.,  16.,   9.,   2.]),
#  array([ 0. ,  1.6,  3.2,  4.8,  6.4,  8. ,  9.6, 11.2, 12.8, 14.4, 16. ]),
#  <a list of 10 Patch objects>)

# %%
from sklearn import preprocessing
le=preprocessing.LabelEncoder()
for column_name in fn.columns:
    if fn[column_name].dtype == object:
        fn[column_name] = le.fit_transform(fn[column_name])
    else:
        pass
fn
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0      9.0        138      73           11         276    120          0   42
# 1     11.0        111      48           16         260     83          1   65
# 2     10.0        113      35           10         269     80          2   59
# 3      7.0        117     100            4         466     97          2   55
# 4      4.0        141      64            3         340    128          0   38
# ..     ...        ...     ...          ...         ...    ...        ...  ...
# 395   12.0        138     108           17         203    128          1   33
# 396    6.0        139      23            3          37    120          2   55
# 397    7.0        162      26           12         368    159          2   40
# 398    5.0        100      79            7         284     95          0   50
# 399    9.0        134      37            0          27    120          1   49
#
#      Education  Urban  US
# 0           17      1   1
# 1           10      1   1
# 2           12      1   1
# 3           14      1   1
# 4           13      1   0
# ..         ...    ...  ..
# 395         14      1   1
# 396         11      0   1
# 397         18      1   1
# 398         12      1   1
# 399         16      1   1
#
# [400 rows x 11 columns]

# %%
highsales=[] 
for i in range(0,len(fn)):
    if (fn.iloc[i,0])>8:
        highsales.append('Yes')
    else:
        highsales.append('No')

# %%
fn['highsales']=highsales
fn
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0      9.0        138      73           11         276    120          0   42
# 1     11.0        111      48           16         260     83          1   65
# 2     10.0        113      35           10         269     80          2   59
# 3      7.0        117     100            4         466     97          2   55
# 4      4.0        141      64            3         340    128          0   38
# ..     ...        ...     ...          ...         ...    ...        ...  ...
# 395   12.0        138     108           17         203    128          1   33
# 396    6.0        139      23            3          37    120          2   55
# 397    7.0        162      26           12         368    159          2   40
# 398    5.0        100      79            7         284     95          0   50
# 399    9.0        134      37            0          27    120          1   49
#
#      Education  Urban  US highsales
# 0           17      1   1       Yes
# 1           10      1   1       Yes
# 2           12      1   1       Yes
# 3           14      1   1        No
# 4           13      1   0        No
# ..         ...    ...  ..       ...
# 395         14      1   1       Yes
# 396         11      0   1        No
# 397         18      1   1        No
# 398         12      1   1        No
# 399         16      1   1       Yes
#
# [400 rows x 12 columns]

# %%
X=(fn.iloc[:,1:10])
X
# Out:
#      CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0          138      73           11         276    120          0   42
# 1          111      48           16         260     83          1   65
# 2          113      35           10         269     80          2   59
# 3          117     100            4         466     97          2   55
# 4          141      64            3         340    128          0   38
# ..         ...     ...          ...         ...    ...        ...  ...
# 395        138     108           17         203    128          1   33
# 396        139      23            3          37    120          2   55
# 397        162      26           12         368    159          2   40
# 398        100      79            7         284     95          0   50
# 399        134      37            0          27    120          1   49
#
#      Education  Urban
# 0           17      1
# 1           10      1
# 2           12      1
# 3           14      1
# 4           13      1
# ..         ...    ...
# 395         14      1
# 396         11      0
# 397         18      1
# 398         12      1
# 399         16      1
#
# [400 rows x 9 columns]

# %%
Y=fn.iloc[:,-1]
Y
# Out:
# 0      Yes
# 1      Yes
# 2      Yes
# 3       No
# 4       No
#       ...
# 395    Yes
# 396     No
# 397     No
# 398     No
# 399    Yes
# Name: highsales, Length: 400, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test = train_test_split(X,Y, test_size=0.2,random_state=40)

# %%
from sklearn.ensemble import RandomForestClassifier
num_trees = 100
max_features = 3
model = RandomForestClassifier(n_estimators=num_trees, max_features=max_features)
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_features=3)

# %%
preds = model.predict(x_test) # predicting on test data set 
pd.Series(preds).value_counts()
# Out:
# No     62
# Yes    18
# dtype: int64

# %%
np.mean(preds==y_test)
# Out:
# 0.85

# %%
preddata=model.predict(X)
fnew=fn
fnew['preddata']=preddata
fnew
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0      9.0        138      73           11         276    120          0   42
# 1     11.0        111      48           16         260     83          1   65
# 2     10.0        113      35           10         269     80          2   59
# 3      7.0        117     100            4         466     97          2   55
# 4      4.0        141      64            3         340    128          0   38
# ..     ...        ...     ...          ...         ...    ...        ...  ...
# 395   12.0        138     108           17         203    128          1   33
# 396    6.0        139      23            3          37    120          2   55
# 397    7.0        162      26           12         368    159          2   40
# 398    5.0        100      79            7         284     95          0   50
# 399    9.0        134      37            0          27    120          1   49
#
#      Education  Urban  US highsales preddata
# 0           17      1   1       Yes      Yes
# 1           10      1   1       Yes      Yes
# 2           12      1   1       Yes      Yes
# 3           14      1   1        No       No
# 4           13      1   0        No       No
# ..         ...    ...  ..       ...      ...
# 395         14      1   1       Yes      Yes
# 396         11      0   1        No       No
# 397         18      1   1        No       No
# 398         12      1   1        No       No
# 399         16      1   1       Yes      Yes
#
# [400 rows x 13 columns]

# %%
pd.crosstab(fn["preddata"],fn["highsales"])
# Out:
# highsales   No  Yes
# preddata
# No         282    8
# Yes          4  106

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
kfold = KFold(n_splits=10, random_state=7)
results = cross_val_score(model, X, Y, cv=kfold)
print(results.mean())
# Out:
# C:\Users\vaishali.gunjal\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# 0.825
